# %%
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sb

# %%
img = cv2.imread('./testimage/messiii.jpg')
img.shape
# Out:
# (1633, 736, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1633, 736)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[321, 489, 248, 248]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h

face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
cropped_image = get_cropped_image_if_2_eyes('./testimage/messiii.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./testimage/messi2.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./testimage/messi2.jpg')
cropped_image_no_2_eyes
#Nothing

# %%
path_to_data = "./Dataset/"
path_to_cr_data = "./Dataset/cropped/"


import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./Dataset/cropped',
#  './Dataset/elon musk',
#  './Dataset/lionel messi',
#  './Dataset/oprah winfrey',
#  './Dataset/warren buffett']

# %%
import shutil    # This code will create the folder
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
# Out:
# cropped
# elon musk
# lionel messi
# oprah winfrey
# warren buffett

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# cropped
# elon musk
# Generating cropped images in folder:  ./Dataset/cropped/elon musk
# lionel messi
# Generating cropped images in folder:  ./Dataset/cropped/lionel messi
# oprah winfrey
# Generating cropped images in folder:  ./Dataset/cropped/oprah winfrey
# warren buffett
# Generating cropped images in folder:  ./Dataset/cropped/warren buffett

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (706, 706, 3)

# %%
import pywt   

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'elon musk': ['./Dataset/cropped/elon musk\\elon musk1.png',
#   './Dataset/cropped/elon musk\\elon musk10.png',
#   './Dataset/cropped/elon musk\\elon musk11.png',
#   './Dataset/cropped/elon musk\\elon musk12.png',
#   './Dataset/cropped/elon musk\\elon musk13.png',
#   './Dataset/cropped/elon musk\\elon musk14.png',
#   './Dataset/cropped/elon musk\\elon musk15.png',
#   './Dataset/cropped/elon musk\\elon musk16.png',
#   './Dataset/cropped/elon musk\\elon musk17.png',
#   './Dataset/cropped/elon musk\\elon musk18.png',
#   './Dataset/cropped/elon musk\\elon musk19.png',
#   './Dataset/cropped/elon musk\\elon musk2.png',
#   './Dataset/cropped/elon musk\\elon musk20.png',
#   './Dataset/cropped/elon musk\\elon musk21.png',
#   './Dataset/cropped/elon musk\\elon musk22.png',
#   './Dataset/cropped/elon musk\\elon musk23.png',
#   './Dataset/cropped/elon musk\\elon musk24.png',
#   './Dataset/cropped/elon musk\\elon musk25.png',
#   './Dataset/cropped/elon musk\\elon musk26.png',
#   './Dataset/cropped/elon musk\\elon musk27.png',
#   './Dataset/cropped/elon musk\\elon musk28.png',
#   './Dataset/cropped/elon musk\\elon musk29.png',
#   './Dataset/cropped/elon musk\\elon musk3.png',
#   './Dataset/cropped/elon musk\\elon musk30.png',
#   './Dataset/cropped/elon musk\\elon musk31.png',
#   './Dataset/cropped/elon musk\\elon musk32.png',
#   './Dataset/cropped/elon musk\\elon musk33.png',
#   './Dataset/cropped/elon musk\\elon musk34.png',
#   './Dataset/cropped/elon musk\\elon musk35.png',
#   './Dataset/cropped/elon musk\\elon musk36.png',
#   './Dataset/cropped/elon musk\\elon musk37.png',
#   './Dataset/cropped/elon musk\\elon musk38.png',
#   './Dataset/cropped/elon musk\\elon musk39.png',
#   './Dataset/cropped/elon musk\\elon musk4.png',
#   './Dataset/cropped/elon musk\\elon musk40.png',
#   './Dataset/cropped/elon musk\\elon musk41.png',
#   './Dataset/cropped/elon musk\\elon musk42.png',
#   './Dataset/cropped/elon musk\\elon musk43.png',
#   './Dataset/cropped/elon musk\\elon musk44.png',
#   './Dataset/cropped/elon musk\\elon musk45.png',
#   './Dataset/cropped/elon musk\\elon musk46.png',
#   './Dataset/cropped/elon musk\\elon musk47.png',
#   './Dataset/cropped/elon musk\\elon musk48.png',
#   './Dataset/cropped/elon musk\\elon musk49.png',
#   './Dataset/cropped/elon musk\\elon musk5.png',
#   './Dataset/cropped/elon musk\\elon musk50.png',
#   './Dataset/cropped/elon musk\\elon musk51.png',
#   './Dataset/cropped/elon musk\\elon musk52.png',
#   './Dataset/cropped/elon musk\\elon musk53.png',
#   './Dataset/cropped/elon musk\\elon musk54.png',
#   './Dataset/cropped/elon musk\\elon musk55.png',
#   './Dataset/cropped/elon musk\\elon musk56.png',
#   './Dataset/cropped/elon musk\\elon musk57.png',
#   './Dataset/cropped/elon musk\\elon musk58.png',
#   './Dataset/cropped/elon musk\\elon musk59.png',
#   './Dataset/cropped/elon musk\\elon musk6.png',
#   './Dataset/cropped/elon musk\\elon musk60.png',
#   './Dataset/cropped/elon musk\\elon musk7.png',
#   './Dataset/cropped/elon musk\\elon musk8.png',
#   './Dataset/cropped/elon musk\\elon musk9.png'],
#  'lionel messi': ['./Dataset/cropped/lionel messi\\lionel messi1.png',
#   './Dataset/cropped/lionel messi\\lionel messi10.png',
#   './Dataset/cropped/lionel messi\\lionel messi11.png',
#   './Dataset/cropped/lionel messi\\lionel messi12.png',
#   './Dataset/cropped/lionel messi\\lionel messi13.png',
#   './Dataset/cropped/lionel messi\\lionel messi14.png',
#   './Dataset/cropped/lionel messi\\lionel messi15.png',
#   './Dataset/cropped/lionel messi\\lionel messi16.png',
#   './Dataset/cropped/lionel messi\\lionel messi17.png',
#   './Dataset/cropped/lionel messi\\lionel messi18.png',
#   './Dataset/cropped/lionel messi\\lionel messi19.png',
#   './Dataset/cropped/lionel messi\\lionel messi2.png',
#   './Dataset/cropped/lionel messi\\lionel messi20.png',
#   './Dataset/cropped/lionel messi\\lionel messi21.png',
#   './Dataset/cropped/lionel messi\\lionel messi22.png',
#   './Dataset/cropped/lionel messi\\lionel messi23.png',
#   './Dataset/cropped/lionel messi\\lionel messi24.png',
#   './Dataset/cropped/lionel messi\\lionel messi25.png',
#   './Dataset/cropped/lionel messi\\lionel messi26.png',
#   './Dataset/cropped/lionel messi\\lionel messi27.png',
#   './Dataset/cropped/lionel messi\\lionel messi28.png',
#   './Dataset/cropped/lionel messi\\lionel messi29.png',
#   './Dataset/cropped/lionel messi\\lionel messi3.png',
#   './Dataset/cropped/lionel messi\\lionel messi30.png',
#   './Dataset/cropped/lionel messi\\lionel messi31.png',
#   './Dataset/cropped/lionel messi\\lionel messi32.png',
#   './Dataset/cropped/lionel messi\\lionel messi33.png',
#   './Dataset/cropped/lionel messi\\lionel messi34.png',
#   './Dataset/cropped/lionel messi\\lionel messi35.png',
#   './Dataset/cropped/lionel messi\\lionel messi36.png',
#   './Dataset/cropped/lionel messi\\lionel messi37.png',
#   './Dataset/cropped/lionel messi\\lionel messi38.png',
#   './Dataset/cropped/lionel messi\\lionel messi39.png',
#   './Dataset/cropped/lionel messi\\lionel messi4.png',
#   './Dataset/cropped/lionel messi\\lionel messi40.png',
#   './Dataset/cropped/lionel messi\\lionel messi5.png',
#   './Dataset/cropped/lionel messi\\lionel messi6.png',
#   './Dataset/cropped/lionel messi\\lionel messi7.png',
#   './Dataset/cropped/lionel messi\\lionel messi8.png',
#   './Dataset/cropped/lionel messi\\lionel messi9.png'],
#  'oprah winfrey': ['./Dataset/cropped/oprah winfrey\\oprah winfrey1.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey10.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey11.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey12.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey13.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey14.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey15.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey16.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey17.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey18.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey19.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey2.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey20.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey21.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey22.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey23.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey24.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey25.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey26.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey27.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey28.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey29.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey3.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey30.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey31.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey32.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey33.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey34.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey35.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey36.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey37.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey38.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey39.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey4.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey40.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey41.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey42.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey43.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey44.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey45.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey46.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey47.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey48.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey5.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey6.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey7.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey8.png',
#   './Dataset/cropped/oprah winfrey\\oprah winfrey9.png'],
#  'warren buffett': ['./Dataset/cropped/warren buffett\\warren buffett1.png',
#   './Dataset/cropped/warren buffett\\warren buffett10.png',
#   './Dataset/cropped/warren buffett\\warren buffett11.png',
#   './Dataset/cropped/warren buffett\\warren buffett12.png',
#   './Dataset/cropped/warren buffett\\warren buffett13.png',
#   './Dataset/cropped/warren buffett\\warren buffett14.png',
#   './Dataset/cropped/warren buffett\\warren buffett15.png',
#   './Dataset/cropped/warren buffett\\warren buffett16.png',
#   './Dataset/cropped/warren buffett\\warren buffett2.png',
#   './Dataset/cropped/warren buffett\\warren buffett3.png',
#   './Dataset/cropped/warren buffett\\warren buffett4.png',
#   './Dataset/cropped/warren buffett\\warren buffett5.png',
#   './Dataset/cropped/warren buffett\\warren buffett6.png',
#   './Dataset/cropped/warren buffett\\warren buffett7.png',
#   './Dataset/cropped/warren buffett\\warren buffett8.png',
#   './Dataset/cropped/warren buffett\\warren buffett9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'elon musk': 0, 'lionel messi': 1, 'oprah winfrey': 2, 'warren buffett': 3}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
X[0]
# Out:
# array([[157],
#        [144],
#        [142],
#        ...,
#        [253],
#        [ 32],
#        [240]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (164, 4096)

# %%
# Model Training
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.7804878048780488

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.93      0.79        14
#            1       0.86      0.75      0.80         8
#            2       0.87      0.81      0.84        16
#            3       0.00      0.00      0.00         3
#
#     accuracy                           0.78        41
#    macro avg       0.60      0.62      0.61        41
# weighted avg       0.74      0.78      0.75        41
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Lenovo\AppData\Roaming\Python\Python311\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
len(X_test)
# Out:
# 41

# %%
# GridSearch

from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.821000
# 1        random_forest    0.706667
# 2  logistic_regression    0.811667
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.9024390243902439

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.6829268292682927

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8292682926829268

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[14,  0,  0,  0],
#        [ 0,  7,  1,  0],
#        [ 0,  1, 15,  0],
#        [ 1,  1,  0,  1]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'elon musk': 0, 'lionel messi': 1, 'oprah winfrey': 2, 'warren buffett': 3}

# %%
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ['saved_model.pkl']
